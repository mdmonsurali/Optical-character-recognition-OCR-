# %%
# !pip install markitdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 723.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 15.3 MB/s eta 0:00:00
# ...

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,564 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,614 kB]
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !ollama pull llama3.1
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏    0 B/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   0% ▕▏  11 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   1% ▕▏  28 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   1% ▕▏  72 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   2% ▕▏ 108 MB/4.9 GB                  pulling manifest
# pulling 667b0c1932bc...   3% ▕▏ 126 MB/4.9 GB                  pulling manifest
# ...

# %%
#!pip install ollama

# %%
import requests

class OllamaClient:
    def __init__(self, model_name="llama3.1"):
        self.base_url = "http://localhost:11434"
        self.model_name = model_name

    def query(self, prompt):
        url = f"{self.base_url}/api/chat"
        payload = {
            "model": self.model_name,
            "messages": [{"role": "user", "content": prompt}],
        }
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()

# Custom Ollama client
client = OllamaClient(model_name="llama3.1")

# Use MarkItDown with Ollama client
from markitdown import MarkItDown

class CustomLLMClient:
    def __init__(self, ollama_client):
        self.ollama_client = ollama_client

    def chat(self, prompt):
        response = self.ollama_client.query(prompt)
        return response.get("choices", [{}])[0].get("message", "")

# Initialize MarkItDown with the custom client
md = MarkItDown(llm_client=CustomLLMClient(client), llm_model="llama3.1")
result = md.convert("/content/ARB#01.pdf")
print(result.text_content)
# Out:
# Berufsunfähigkeitsbedingungen für Akademiker im Rahmen des
# MLP Vorsorgemanagements
# (Stand 01.07.1997/EZM 797)
#
# § 1 Was ist versichert?
#
# den.
#
# (1)  W ird  der  Versicherte  während  der  Dauer  dieser  Berufs- § 2 Wann liegt Berufsunfähigkeit vor?
# unfähigkeits(zusatz)versicherung  zu  mindestens  50  Prozent
# berufsunfähig,  so  erbringen  wir  folgende  Versicherungslei-
# stungen:
#
# (1)  a)  Vollständige  Berufsunfähigkeit  im  Sinne  dieser  Bedin-
# gungen liegt vor, wenn und solange der Versicherte, der
# -  ein  Studium  an  einer  staatlich  anerkannten  Universität,
# a)  Beitragsbefreiung:  Wir  befreien  Sie  von  der  Beitragszah- Fachhochschule  oder  Berufsakademie  innerhalb  der  Euro-
# lungspflicht  für  die  im  Versicherungsschein  bezeichneten päischen Union abgeschlossen hat und
# Versicherungen.
#
# -  zum  Zeitpunkt  des  Eintritts  der  Berufsunfähigkeit  einen
# Beruf  ausübt,  der  einer  akademischen  Ausbildung  ent-
#
# ...

# %%
from markitdown import MarkItDown

markitdown = MarkItDown()
result = markitdown.convert("/content/Page-2168.pdf")
print(result.text_content)

# %%
result = markitdown.convert("/content/Page-2168.pdf")
print(result.text_content)

# %%
# Access the text content from the result
markdown_content = result.text_content

# Specify the output markdown file path
output_file_path = "/content/converted_page.md"

# Write the content to the markdown file
with open(output_file_path, "w", encoding="utf-8") as markdown_file:
    markdown_file.write(markdown_content)

print(f"Markdown file saved to: {output_file_path}")
# Out:
# Markdown file saved to: /content/converted_page.md
